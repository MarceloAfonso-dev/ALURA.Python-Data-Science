# %%
lista
# Out:
# ['Ricardo Vieira', 'Marcelo Afonso']

# %%
i = 0
lista = ['Ricardo Vieira', 'Marcelo Afonso']

while i < len(lista):
    print(f'Olá {lista[i]}')
    salario = float(input('Digite o seu salário: R$'))

    if salario <= 1000:
        print('Você é zoado')
    elif salario > 1000 and salario <= 5000:
        print('Você é normal')
    else:
        print('Você é rico')
    i += 1

print(f'E além disso, você ganha R$ {12*salario:.2f}')
# Out:
# Olá Ricardo Vieira
# Você é zoado
# Olá Marcelo Afonso
# Você é normal
# E além disso, você ganha R$ 60000.00

# %%
if 'Marcelo Afonso' in lista:
    print('Marcelo está na lista')
# Out:
# Marcelo está na lista

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for j in lista:
    print(j)
# Out:
# Ricardo Vieira
# Marcelo Afonso

# %%
linguagem = 'Python'
print(linguagem[0], linguagem[1], linguagem[2], linguagem[-3], linguagem[-2], linguagem[-1])
# Out:
# P y t h o n

# %%
lista.append('Novo Elemento')
print(lista)
# Out:
# ['Ricardo Vieira', 'Marcelo Afonso', 'Novo Elemento']

# %%
print(len(lista))
lista[0:2]
# Out:
# 3
# ['Ricardo Vieira', 'Marcelo Afonso']

# %%
raca_caes = ['Labrador Retriever',
             'Bulldog Francês',
             'Pastor Alemão',
             'Poodle']
raca_caes.insert(1, 'Golden Retriever')
raca_caes
# Out:
# ['Labrador Retriever',
#  'Golden Retriever',
#  'Bulldog Francês',
#  'Pastor Alemão',
#  'Poodle']

# %%
raca_caes.pop(1)
# Out:
# 'Golden Retriever'

# %%
raca_caes.index('Pastor Alemão')
# Out:
# 2

# %%
raca_caes.sort()
raca_caes
# Out:
# ['Bulldog Francês', 'Labrador Retriever', 'Pastor Alemão', 'Poodle']

# %%
lista = [1, 2, 3, 4]
elemento = lista.pop(2)  # Remove e retorna o elemento na posição 2
print(lista)  # Saída: [1, 2, 4]
print(elemento)  # Saída: 3

ultimo_elemento = lista.pop()  # Remove e retorna o último elemento
print(lista)  # Saída: [1, 2]
print(ultimo_elemento)  # Saída: 4
# Out:
# [1, 2, 4]
# 3
# [1, 2]
# 4

# %%
json = {
    'nome': 'Ricardo Vieira',
    'idade': 25,
    'cidade': 'São Paulo'
}
json
# Out:
# {'nome': 'Ricardo Vieira', 'idade': 25, 'cidade': 'São Paulo'}

# %%
json['nome']
json['idade'] = 26
json['Salario'] = 1000
json
# Out:
# {'nome': 'Ricardo Vieira', 'idade': 26, 'cidade': 'São Paulo', 'Salario': 1000}

# %%
json.pop('cidade')
json
# Out:
# {'nome': 'Ricardo Vieira', 'idade': 26, 'Salario': 1000}

# %%
json.items()
# Out:
# dict_items([('nome', 'Ricardo Vieira'), ('idade', 26), ('Salario', 1000)])

# %%
json.keys()
# Out:
# dict_keys(['nome', 'idade', 'Salario'])

# %%
json.values()
# Out:
# dict_values(['Ricardo Vieira', 26, 1000])

# %%
for valores in json.values():
    print(valores)
# Out:
# Ricardo Vieira
# 26
# 1000

# %%
for chaves, valores in json.items():
    print(chaves, valores)
# Out:
# nome Ricardo Vieira
# idade 26
# Salario 1000

# %%
dir(json)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']
